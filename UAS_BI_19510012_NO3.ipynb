# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel('E:\KULIAH\Semester 7\BI\data_UAS-main/caesarian.xlsx')
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian
# 0           0
# 1           1
# 2           0
# 3           0
# ...

# %%
import math
dis = []
for i in range(80):
    dis.append(math.sqrt((float(df.iloc[i]['Usia'])-25)**2+
                         (float(df.iloc[i]['Kelahiran_ke-'])- 1)**2+
                         (float(df.iloc[i]['Waktu_Kelahiran'])-0)**2+
                         (float(df.iloc[i]['Tekanan_darah'])-1)**2))

# %%
df['dis'] = dis
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian       dis
# 0           0  3.162278
# 1           1  1.414214
# ...

# %%
df.sort_values('dis')
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 16    25              1                0              1                 0
# 46    26              1                0              1                 0
# 68    25              1                0              0                 0
# 55    25              2                0              1                 0
# 30    25              1                0              0                 0
# ..   ...            ...              ...            ...               ...
# 42    36              1                1              2                 0
# 44    36              4                0              2                 1
# 18    37              3                0              1                 1
# 74    38              3                2              2                 1
# 31    40              1                0              1                 1
#
#     Caesarian        dis
# 16          0   0.000000
# 46          0   1.000000
# ...

# %%
y = df.sort_values('dis').head(5)
y
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 16    25              1                0              1                 0
# 46    26              1                0              1                 0
# 68    25              1                0              0                 0
# 55    25              2                0              1                 0
# 30    25              1                0              0                 0
#
#     Caesarian  dis
# 16          0  0.0
# 46          0  1.0
# 68          1  1.0
# 55          0  1.0
# 30          0  1.0

# %%
z = y["Caesarian"]
z
# Out:
# 16    0
# 46    0
# 68    1
# 55    0
# 30    0
# Name: Caesarian, dtype: int64

# %%
np.mean(z)
# Out:
# 0.2

# %%
df.to_excel('E:\KULIAH\Semester 7\BI\data_UAS-main/output_no2.xlsx')

# %%
import math 
dis = []
for i in range(80):
    dis.append(math.sqrt((float(df.iloc[i]['Usia'])-35)**2+
                         (float(df.iloc[i]['Kelahiran_ke-'])- 1)**2+
                         (float(df.iloc[i]['Waktu_Kelahiran'])-1)**2+
                         (float(df.iloc[i]['Tekanan_darah'])-2)**2))

# %%
df['dis'] = dis
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian        dis
# 0           0  13.038405
# 1           1   9.165151
# ...

# %%
df.sort_values('dis')
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 42    36              1                1              2                 0
# 65    35              2                0              1                 0
# 10    36              1                0              1                 0
# 53    35              1                1              0                 0
# 36    33              1                1              1                 0
# ..   ...            ...              ...            ...               ...
# 41    19              1                0              1                 0
# 61    19              1                0              1                 0
# 26    18              1                1              2                 1
# 25    18              1                0              1                 0
# 70    17              1                0              0                 0
#
#     Caesarian        dis
# 42          1   1.000000
# 65          1   1.732051
# ...

# %%
y = df.sort_values('dis').head(5)
y
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 42    36              1                1              2                 0
# 65    35              2                0              1                 0
# 10    36              1                0              1                 0
# 53    35              1                1              0                 0
# 36    33              1                1              1                 0
#
#     Caesarian       dis
# 42          1  1.000000
# 65          1  1.732051
# 10          0  1.732051
# 53          0  2.000000
# 36          0  2.236068

# %%
z = y["Caesarian"]
z
# Out:
# 42    1
# 65    1
# 10    0
# 53    0
# 36    0
# Name: Caesarian, dtype: int64

# %%
np.mean(z)
# Out:
# 0.4

# %%
df.to_excel('E:\KULIAH\Semester 7\BI\UAS_BI/output_no2b.xlsx')
# Out:
#   File "C:\Users\asus\AppData\Local\Temp/ipykernel_9660/3908805497.py", line 1
#     df.to_excel('E:\KULIAH\Semester 7\BI\UAS_BI/output_no2b.xlsx')
#                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 23-25: truncated \UXXXXXXXX escape
